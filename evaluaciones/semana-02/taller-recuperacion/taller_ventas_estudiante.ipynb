# %% [markdown]
# # Taller de recuperación - Árboles para pronosticar ventas
#
# **Machine Learning II · Universidad Externado de Colombia**
# **Fecha:** 3 de agosto de 2026 · **Trabajo en parejas · 60 minutos**
#
# Escriban aquí los nombres y códigos de ambos integrantes. Este notebook debe ejecutar de principio a fin. Los cálculos de Gini y del árbol manual se entregan también escritos a mano.

# %% [markdown]
# ## 1. Cargar y explorar los datos
#
# El archivo está en `ventas_tienda.csv`. Importe las librerías que necesite, cargue el CSV y muestre evidencia suficiente para responder:
#
# 1. ¿Cuántas observaciones y variables hay?
# 2. ¿Cuál es la variable objetivo?
# 3. ¿Qué columnas usarán como predictores y cuál excluirán? Justifiquen la exclusión.
# 4. ¿Hay valores faltantes?

# %%
# Escriban aquí su código de carga y exploración.

# %% [markdown]
# ## 2. Baseline y separación
#
# Usen exactamente `test_size=0.25` y `random_state=42`. Calculen un baseline que prediga para toda validación la **mediana de `unidades_vendidas` en entrenamiento**. Reporten la mediana y el MAE de validación.
#
# Expliquen en dos o tres líneas por qué la mediana debe calcularse solo con entrenamiento y por qué no conviene usar `dia` como predictor.

# %%
# Escriban aquí la partición, el baseline y el MAE.

# %% [markdown]
# ## 3. Comparar árboles de regresión
#
# Entrenen exactamente estas configuraciones con `random_state=42`:
#
# | Modelo | max_depth | min_samples_leaf |
# |---|---:|---:|
# | simple | 1 | 8 |
# | moderado | 2 | 5 |
# | profundo | 4 | 3 |
# | sin_limite | None | 1 |
#
# Para cada modelo reporten MAE de entrenamiento y validación. Construyan una tabla comparativa y seleccionen una configuración **sin usar ningún dato adicional**.

# %%
# Escriban aquí el entrenamiento y la tabla comparativa.

# %% [markdown]
# ## 4. Decisión final
#
# Respondan en máximo seis líneas:
#
# 1. ¿Qué modelo escogerían y con qué evidencia?
# 2. ¿Cuál configuración muestra mayor riesgo de overfitting?
# 3. ¿El modelo elegido mejora el baseline?
# 4. Mencionen una limitación concreta del conjunto de datos.

# %%
# Pueden imprimir aquí los valores que respalden su respuesta.

# %% [markdown]
# ## Entrega
#
# Al cierre de la clase del **3 de agosto de 2026**, una persona de la pareja envía un ZIP con este notebook ejecutado y el PDF o fotografías legibles de los cálculos manuales.
#
# - Teams y correo son equivalentes; se conserva la primera entrega recibida.
# - Correo: `wilmer.pineda@uexternado.edu.co`
# - Asunto: `Taller recuperación ML2 - Apellido1 y Apellido2`
# - Archivo: `Taller_Recuperacion_Apellido1_Apellido2.zip`
